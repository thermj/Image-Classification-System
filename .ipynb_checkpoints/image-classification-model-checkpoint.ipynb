# %% [markdown]
# # Importing Libraries And Datasets

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

# %%
data_train_path = 'Fruits_Vegetables/train'
data_test_path = 'Fruits_Vegetables/test'
data_val_path = 'Fruits_Vegetables/validation'

# %%
# Scaling all the images to the same size
img_width = 180
img_height = 180

# %%
data_train = tf.keras.utils.image_dataset_from_directory(
    data_train_path,
    shuffle=True,
    image_size=(img_width, img_height),
    batch_size=32,
    validation_split=False
)
# Out:
# Found 3115 files belonging to 36 classes.

# %%
data_category = data_train.class_names

# %%
data_category
# Out:
# ['apple',
#  'banana',
#  'beetroot',
#  'bell pepper',
#  'cabbage',
#  'capsicum',
#  'carrot',
#  'cauliflower',
#  'chilli pepper',
#  'corn',
#  'cucumber',
#  'eggplant',
#  'garlic',
#  'ginger',
#  'grapes',
#  'jalepeno',
#  'kiwi',
#  'lemon',
#  'lettuce',
#  'mango',
#  'onion',
#  'orange',
#  'paprika',
#  'pear',
#  'peas',
#  'pineapple',
#  'pomegranate',
#  'potato',
#  'raddish',
#  'soy beans',
#  'spinach',
#  'sweetcorn',
#  'sweetpotato',
#  'tomato',
#  'turnip',
#  'watermelon']

# %%
data_val = tf.keras.utils.image_dataset_from_directory(
    data_val_path,
    shuffle=False,
    image_size=(img_width, img_height),
    batch_size=32,
    validation_split=False
)
# Out:
# Found 351 files belonging to 36 classes.

# %%
data_test = tf.keras.utils.image_dataset_from_directory(
    data_test_path,
    shuffle=False,
    image_size=(img_width, img_height),
    batch_size=32,
    validation_split=False
)
# Out:
# Found 359 files belonging to 36 classes.

# %%
# Printing imgs from train dataset
plt.figure(figsize=(10,10))
for images, labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype('uint8'))
        plt.title(data_category[labels[i].numpy()])
        plt.axis('off')
plt.show()

# %% [markdown]
# # Model Building
# - CNN Model

# %%
from tensorflow.keras.models import Sequential

# %%
data_train
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
# All the images will be saved in RGB format.
model = Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(len(data_category))
])

# %% [markdown]
# ## Compile the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ## Train the model

# %%
epochs_size = 25
history = model.fit(data_train, validation_data=data_val, epochs=epochs_size)
# Out:
# Epoch 1/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 28s 270ms/step - accuracy: 0.0666 - loss: 3.4663 - val_accuracy: 0.3362 - val_loss: 2.2824
# Epoch 2/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 25s 258ms/step - accuracy: 0.2979 - loss: 2.4251 - val_accuracy: 0.6410 - val_loss: 1.4402
# Epoch 3/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 28s 284ms/step - accuracy: 0.4853 - loss: 1.7939 - val_accuracy: 0.8063 - val_loss: 0.7926
# Epoch 4/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 26s 264ms/step - accuracy: 0.6567 - loss: 1.2002 - val_accuracy: 0.9060 - val_loss: 0.4350
# Epoch 5/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 27s 270ms/step - accuracy: 0.8391 - loss: 0.5810 - val_accuracy: 0.9402 - val_loss: 0.3668
# Epoch 6/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 27s 270ms/step - accuracy: 0.9335 - loss: 0.2643 - val_accuracy: 0.9459 - val_loss: 0.2963
# Epoch 7/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 27s 277ms/step - accuracy: 0.9640 - loss: 0.1667 - val_accuracy: 0.9259 - val_loss: 0.4277
# Epoch 8/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 29s 290ms/step - accuracy: 0.9708 - loss: 0.1334 - val_accuracy: 0.9658 - val_loss: 0.2943
# Epoch 9/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 28s 280ms/step - accuracy: 0.9832 - loss: 0.0976 - val_accuracy: 0.9658 - val_loss: 0.2683
# Epoch 10/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 30s 306ms/step - accuracy: 0.9910 - loss: 0.0671 - val_accuracy: 0.9630 - val_loss: 0.3504
# Epoch 11/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 29s 289ms/step - accuracy: 0.9904 - loss: 0.0637 - val_accuracy: 0.9630 - val_loss: 0.2974
# Epoch 12/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 38s 387ms/step - accuracy: 0.9909 - loss: 0.0614 - val_accuracy: 0.9573 - val_loss: 0.3046
# Epoch 13/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 43s 435ms/step - accuracy: 0.9899 - loss: 0.0540 - val_accuracy: 0.9658 - val_loss: 0.3002
# Epoch 14/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 33s 338ms/step - accuracy: 0.9931 - loss: 0.0463 - val_accuracy: 0.9601 - val_loss: 0.3015
# Epoch 15/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 28s 285ms/step - accuracy: 0.9906 - loss: 0.0575 - val_accuracy: 0.9658 - val_loss: 0.2932
# Epoch 16/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 28s 280ms/step - accuracy: 0.9866 - loss: 0.0606 - val_accuracy: 0.9658 - val_loss: 0.2664
# Epoch 17/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 28s 284ms/step - accuracy: 0.9878 - loss: 0.0566 - val_accuracy: 0.9630 - val_loss: 0.2646
# Epoch 18/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 28s 287ms/step - accuracy: 0.9926 - loss: 0.0418 - val_accuracy: 0.9687 - val_loss: 0.2165
# Epoch 19/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 28s 283ms/step - accuracy: 0.9926 - loss: 0.0433 - val_accuracy: 0.9601 - val_loss: 0.2834
# Epoch 20/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 28s 283ms/step - accuracy: 0.9905 - loss: 0.0459 - val_accuracy: 0.9630 - val_loss: 0.2740
# Epoch 21/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 35s 352ms/step - accuracy: 0.9931 - loss: 0.0502 - val_accuracy: 0.9658 - val_loss: 0.2387
# Epoch 22/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 37s 368ms/step - accuracy: 0.9885 - loss: 0.0716 - val_accuracy: 0.9658 - val_loss: 0.2435
# Epoch 23/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 33s 338ms/step - accuracy: 0.9913 - loss: 0.0393 - val_accuracy: 0.9630 - val_loss: 0.2678
# Epoch 24/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 37s 372ms/step - accuracy: 0.9927 - loss: 0.0447 - val_accuracy: 0.9544 - val_loss: 0.2731
# Epoch 25/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 28s 281ms/step - accuracy: 0.9929 - loss: 0.0433 - val_accuracy: 0.9658 - val_loss: 0.2664

# %% [markdown]
# ## Evaluate the model

# %%
loss, accuracy = model.evaluate(data_val)
print(f'Accuracy: {accuracy}')
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 267ms/step - accuracy: 0.9481 - loss: 0.3610
# Accuracy: 0.9658119678497314

# %% [markdown]
# ## Plotting the training history.

# %%
# Plot graphs.
import matplotlib.pyplot as plt

# Define the range of epochs
epochs_range = range(epochs_size)

# Plot Training and Validation Accuracy
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, history.history['accuracy'], label='Training Accuracy')
plt.plot(epochs_range, history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# Plot Training and Validation Loss
plt.subplot(1, 2, 2)
plt.plot(epochs_range, history.history['loss'], label='Training Loss')
plt.plot(epochs_range, history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper right')

# Show the plots
plt.tight_layout()
plt.show()

# %%
image = 'Apple.jpg'
image = tf.keras.utils.load_img(image, target_size=(img_height, img_width))
img_arr = tf.keras.utils.img_to_array(image)
img_bat = tf.expand_dims(img_arr, 0)

# %%
pred = model.predict(img_bat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
score = tf.nn.softmax(pred)

# %%
print('Vegetable/Fruit in image is {} with accuracy of {:.2f}'.format(data_category[np.argmax(score)], np.max(score) * 100))
# Out:
# Vegetable/Fruit in image is apple with accuracy of 99.91

# %%
model.save('Image_classify_keras.keras')
